# %%
"""Check AudioMNIST data"""

import torchaudio
import torch

# %%
file_path_0 = 'D:\\Thesis\\Data Sets\\Audio\\AudioMNIST\\audio\\02\\0_02_42.wav'
signal_0, sr_0 = torchaudio.load(file_path_0)
file_path_1 = 'D:\\Thesis\\Data Sets\\Audio\\AudioMNIST\\audio\\02\\1_02_45.wav'
signal_1, sr_1 = torchaudio.load(file_path_1)
file_path_2 = 'D:\\Thesis\\Data Sets\\Audio\\AudioMNIST\\audio\\02\\2_02_40.wav'
signal_2, sr_2 = torchaudio.load(file_path_2)
file_path_3 = 'D:\\Thesis\\Data Sets\\Audio\\AudioMNIST\\audio\\02\\3_02_47.wav'
signal_3, sr_3 = torchaudio.load(file_path_3)
file_path_4 = 'D:\\Thesis\\Data Sets\\Audio\\AudioMNIST\\audio\\02\\4_02_46.wav'
signal_4, sr_4 = torchaudio.load(file_path_4)
file_path_5 = 'D:\\Thesis\\Data Sets\\Audio\\AudioMNIST\\audio\\02\\5_02_41.wav'
signal_5, sr_5 = torchaudio.load(file_path_5)
file_path_6 = 'D:\\Thesis\\Data Sets\\Audio\\AudioMNIST\\audio\\02\\6_02_18.wav'
signal_6, sr_6 = torchaudio.load(file_path_6)
file_path_7 = 'D:\\Thesis\\Data Sets\\Audio\\AudioMNIST\\audio\\02\\7_02_13.wav'
signal_7, sr_7 = torchaudio.load(file_path_7)
file_path_8 = 'D:\\Thesis\\Data Sets\\Audio\\AudioMNIST\\audio\\02\\8_02_11.wav'
signal_8, sr_8 = torchaudio.load(file_path_8)
file_path_9 = 'D:\\Thesis\\Data Sets\\Audio\\AudioMNIST\\audio\\60\\9_60_9.wav'
signal_9, sr_9 = torchaudio.load(file_path_9)

# %%
from IPython.display import Audio
Audio(data=signal_0, rate=sr_0)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=signal_1, rate=sr_1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=signal_2, rate=sr_2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=signal_3, rate=sr_3)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=signal_4, rate=sr_4)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=signal_5, rate=sr_5)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=signal_6, rate=sr_6)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=signal_7, rate=sr_7)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=signal_8, rate=sr_8)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=signal_9, rate=sr_9)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
"""Testing preprocessed Data"""

X = torch.load(r"D:\Thesis\Data Sets\Audio\AudioMNIST\preprocessed_data\signals.pt")

# %%
Audio(data=X[0], rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=X[90], rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=X[1610], rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=X[1676], rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=X[1711], rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=X[1750], rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=X[1814], rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=X[1870], rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=X[1908], rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=X[1960], rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
