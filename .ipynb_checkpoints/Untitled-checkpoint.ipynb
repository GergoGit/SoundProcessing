# %%
"""Check AudioMNIST data"""

import torchaudio
import torch
from IPython.display import Audio

# %%
file_path_0 = 'D:\\Thesis\\Data Sets\\Audio\\\SpeechCommands\\one\\0a2b400e_nohash_0.wav'
signal_0, sr_0 = torchaudio.load(file_path_0)
Audio(data=signal_0, rate=sr_0)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
file_path_down = 'D:\\Thesis\\Data Sets\\Audio\\\SpeechCommands\\down\\0a2b400e_nohash_4.wav'
signal, sr = torchaudio.load(file_path_down)
Audio(data=signal, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sr_down
# Out:
# 16000
